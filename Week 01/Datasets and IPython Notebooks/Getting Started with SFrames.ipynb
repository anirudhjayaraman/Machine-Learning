# %%
import graphlab

# %% [markdown]
# #Load Tabular Dataset

# %%
sf = graphlab.SFrame('people-example.csv')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to anirudhj@igidr.ac.inand will expire on September 22, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-13383 - Server binary: /home/anirudh/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1443119350.log
# [INFO] GraphLab Server Version: 1.6
# PROGRESS: Finished parsing file /home/anirudh/Coding/Python/ML in Python/people-example.csv
# PROGRESS: Parsing completed. Parsed 7 lines in 0.055179 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# ...

# %% [markdown]
# #SFrame Basics

# %%
sf # to view the first few lines of the table
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.head() # equivalent of the above code
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.tail() # last few lines of the table
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %% [markdown]
# #GraphLab Canvas

# %%
# Take any data structure in GraphLab Create
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:39346/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target('ipynb')

# %%
sf.show()

# %%
sf['age'].show(view = 'Categorical')

# %% [markdown]
# #Inspect Columns of Data

# %%
sf['Country']
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'USA', 'Poland', 'United States', 'Switzerland']

# %%
sf['age']
# Out:
# dtype: int
# Rows: 7
# [24, 23, 22, 23, 23, 22, 25]

# %%
sf['age'].mean()
# Out:
# 23.142857142857146

# %%
sf['age'].max()
# Out:
# 25

# %% [markdown]
# #Create New Columns

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf['Full Name'] = sf['First Name'] + sf['Last Name']

# %%
sf['Full Name'] = sf['First Name'] + '' + sf['Last Name']

# %%
sf['Full Name'] = sf['First Name'] + ' ' + sf['Last Name']

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |   Full Name    |
# +------------+-----------+---------------+-----+----------------+
# |    Bob     |   Smith   | United States |  24 |   Bob Smith    |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
sf['Country'].show()

# %%
def transformCountry(country):
    if country == "USA":
        return "United States"
    else:
        return country

# %%
newCountries = sf['Country'].apply(transformCountry)

# %%
sf['Country'] = newCountries

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |   Full Name    |
# +------------+-----------+---------------+-----+----------------+
# |    Bob     |   Smith   | United States |  24 |   Bob Smith    |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   | United States |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
sf['Country'].show()
